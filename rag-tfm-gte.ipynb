# %%
import os
import pprint
from dotenv import load_dotenv
from typing import List, Optional
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_qdrant import Qdrant
from langchain_community.llms import Ollama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.documents import Document
from langgraph.graph import START, END, StateGraph
from pydantic import BaseModel, Field
from qdrant_client import QdrantClient
from langchain_ollama import OllamaLLM
from pydantic import BaseModel, Field
from typing import List, Optional
from langchain_core.documents import Document
from langgraph.graph import START, StateGraph
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams
import torch
from langchain.embeddings.base import Embeddings

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:98;} </style>"))
# Out:
# <style>.container { width:98;} </style>

# %%
# Cargar variables de entorno 
load_dotenv()
print("Variables de entorno cargadas")
# Out:
# Variables de entorno cargadas

# %%
# LLM
llm = OllamaLLM(model="hf.co/bartowski/Llama-3.2-3B-Instruct-GGUF:Q8_0")
print("LLM inicializado")
# ollama run hf.co/bartowski/Llama-3.2-3B-Instruct-GGUF:Q8_0
# Out:
# LLM inicializado

# %% [markdown]
# __Modelo de embeddings  Alibaba-NLP/gte-multilingual-base__

# %%
# Modelo de EmbeddingsAlibaba-NLP/gte-multilingual-base
embeddings = HuggingFaceEmbeddings(model_name="", model_kwargs={"trust_remote_code": True})

# Configuración
COLLECTION_NAME = "idearq-gte"
VECTOR_SIZE = 768
#model_embbedings_e5_instruct = "multilingual-e5-large-instruct"  

# Inicializar clientes
client = QdrantClient(url="http://localhost:6333")

# 1. Borrar colección (si ya existe)
if COLLECTION_NAME in [c.name for c in client.get_collections().collections]:
    client.delete_collection(COLLECTION_NAME)

# 2. Crear colección
client.recreate_collection(
    collection_name=COLLECTION_NAME,
    vectors_config=VectorParams(size=VECTOR_SIZE, distance=Distance.COSINE),
)
# Out:
# Some weights of the model checkpoint at Alibaba-NLP/gte-multilingual-base were not used when initializing NewModel: ['classifier.bias', 'classifier.weight']
# - This IS expected if you are initializing NewModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing NewModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# C:\Users\elevi\AppData\Local\Temp\ipykernel_11540\443072613.py:17: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   client.recreate_collection(
# True

# %%
client = QdrantClient(url="http://localhost:6333")
info = client.get_collection(COLLECTION_NAME)
assert info.config.params.vectors.size == 768, "La colección no está configurada para vectores de 768 dimensiones."
print("¡La dimensión de los vectores (768) es correcta!")
# Out:
# ¡La dimensión de los vectores (768) es correcta!

# %%
import logging
from pathlib import Path
from langchain.document_loaders import PyMuPDFLoader

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

all_docs = []
folder_path = Path("pdf_articulos_idearq/") 

logging.info(f"Iniciando la carga de documentos desde: {folder_path.resolve()}")

if not folder_path.is_dir():
    logging.error(f"El directorio especificado no existe: {folder_path.resolve()}")
else:
    # Usamos .glob() que es eficiente para buscar archivos
    for pdf_file in folder_path.glob("*.pdf"):
        try:
            loader = PyMuPDFLoader(str(pdf_file), mode="single")
            docs_from_file = loader.load()
            all_docs.extend(docs_from_file)
            # logging.debug(f"Cargado: {pdf_file.name}") 
        except Exception as e:
            # Este bloque capturará si un PDF específico está dañado y no se puede leer
            logging.warning(f"No se pudo cargar el archivo '{pdf_file.name}'. Saltando. Error: {e}")

    logging.info(f"Carga finalizada. Se han cargado un total de {len(all_docs)} documentos.")
# Out:
# 2025-08-02 13:27:19,891 - INFO - Iniciando la carga de documentos desde: C:\Users\elevi\Documents\CSIC\RAG\pdf_articulos_idearq
# 2025-08-02 13:28:37,333 - INFO - Carga finalizada. Se han cargado un total de 300 documentos.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
import logging

# Configurar un logger para controlar el proceso
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

text_splitter_config = {
    "chunk_size": 1000,
    "chunk_overlap": 200, # 15-20% de chunk_size
    "length_function": len,
    "add_start_index": True,
    "separators": ["\n\n", "\n", ". ", " ", ""],
}

# El operador ** desempaqueta el diccionario como argumentos 
text_splitter = RecursiveCharacterTextSplitter(**text_splitter_config)

all_splits = text_splitter.split_documents(all_docs)

logging.info(f"Se dividieron {len(all_docs)} documentos en un total de {len(all_splits)} chunks.")
# Out:
# 2025-08-02 13:28:43,879 - INFO - Se dividieron 300 documentos en un total de 50687 chunks.

# %%
from langchain_qdrant import Qdrant

QDRANT_URL = "http://localhost:6333"
COLLECTION_NAME = "idearq-gte"

# Configura el logger si no lo has hecho en una celda anterior.
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# 3. CREAR EL OBJETO 'vector_store' 
# Primero, nos conectamos al cliente de Qdrant 
client = QdrantClient(url=QDRANT_URL)

# Ahora, creamos la variable 'vector_store', que es el objeto de LangChain
# Este objeto "envuelve" al cliente y sabe cómo usar la función de embeddings
logging.info(f"Conectando a la colección '{COLLECTION_NAME}' a través de LangChain...")
vector_store = Qdrant(
    client=client,
    collection_name=COLLECTION_NAME,
    embeddings=embeddings,
)
logging.info("Objeto 'vector_store' listo para la ingesta")

# 4. INGESTA DE DOCUMENTOS 
logging.info(f"Iniciando la ingesta de {len(all_splits)} chunks...")

vector_store.add_documents(all_splits)

logging.info("Ingesta completada")
# Out:
# 2025-08-02 13:28:43,989 - INFO - HTTP Request: GET http://localhost:6333 "HTTP/1.1 200 OK"
# 2025-08-02 13:28:43,994 - INFO - Conectando a la colección 'idearq-gte' a través de LangChain...
# C:\Users\elevi\AppData\Local\Temp\ipykernel_11540\2025586897.py:16: LangChainDeprecationWarning: The class `Qdrant` was deprecated in LangChain 0.1.2 and will be removed in 0.5.0. Use :class:`~QdrantVectorStore` instead.
#   vector_store = Qdrant(
# 2025-08-02 13:28:43,997 - INFO - Objeto 'vector_store' listo para la ingesta
# 2025-08-02 13:28:43,998 - INFO - Iniciando la ingesta de 50687 chunks...
# 2025-08-02 13:29:17,002 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:29:51,317 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:30:21,582 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:30:57,345 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:31:28,672 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:32:01,821 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:32:34,964 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:33:03,853 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:33:30,778 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:33:58,139 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:34:29,442 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:34:53,937 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:35:18,071 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:35:45,251 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:36:16,658 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:36:47,011 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:37:19,963 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:37:57,212 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:38:35,613 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:39:08,625 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:39:45,775 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:40:17,686 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:40:52,402 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:41:25,082 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:41:55,480 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:42:19,126 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:42:45,455 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:43:09,984 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:43:41,719 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:44:19,472 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:44:54,816 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:45:27,533 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:46:00,316 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:46:33,961 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:47:06,102 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:47:36,337 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:48:07,928 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:48:34,178 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:49:20,080 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:49:47,991 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:50:29,263 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13:51:03,507 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 13
- INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:20:30,107 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:20:56,498 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:21:18,012 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:21:39,693 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:22:10,246 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:22:36,683 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:23:04,582 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:23:32,538 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:24:02,596 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:24:23,565 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:24:45,792 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:25:07,367 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:25:32,449 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:25:59,059 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:26:24,978 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:26:52,366 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:27:21,093 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:27:47,817 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:28:16,685 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:28:43,975 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:29:03,961 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:29:30,624 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:29:57,716 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:30:26,684 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:30:49,056 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:31:13,981 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:31:38,054 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:32:06,599 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:32:36,488 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:33:00,145 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:33:26,959 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:33:57,109 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:34:24,004 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:34:47,520 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:35:15,888 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:35:42,060 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:36:10,711 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:36:45,758 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:37:14,564 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:37:44,437 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:38:12,239 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:38:43,468 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:39:11,818 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:39:38,204 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:40:05,117 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:40:32,386 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:40:57,780 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:41:25,126 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:41:52,944 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:42:21,893 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:42:50,843 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:43:14,990 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:43:42,650 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:44:06,704 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:44:29,926 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:44:57,248 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:45:22,811 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:45:46,314 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:46:08,156 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:46:33,201 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:46:56,983 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:47:23,783 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:47:49,708 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:48:17,605 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:48:39,440 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-02 19:48:39,897 - INFO - Ingesta completada

# %%
import torch
from langchain_huggingface import HuggingFaceEmbeddings
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams

# --- Código Corregido para usar GPU ---

# 1. Detectar si hay una GPU disponible
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Usando dispositivo para embeddings: {device}')

# 2. Configurar los argumentos del modelo para incluir el dispositivo y trust_remote_code
model_kwargs = {
    'device': device,
    'trust_remote_code': True
}

# 3. Inicializar el modelo de embeddings con los argumentos correctos
embeddings = HuggingFaceEmbeddings(
    model_name="Alibaba-NLP/gte-multilingual-base",
    model_kwargs=model_kwargs
)

# Configuración
COLLECTION_NAME = "idearq-gte"
VECTOR_SIZE = 768

# Inicializar clientes
client = QdrantClient(url="http://localhost:6333")

# 1. Borrar colección (si ya existe)
if COLLECTION_NAME in [c.name for c in client.get_collections().collections]:
    client.delete_collection(COLLECTION_NAME)

# 2. Crear colección
# Nota: La advertencia de 'recreate_collection' es normal.
client.recreate_collection(
    collection_name=COLLECTION_NAME,
    vectors_config=VectorParams(size=VECTOR_SIZE, distance=Distance.COSINE),
)

print(f"Colección '{COLLECTION_NAME}' creada/recreada exitosamente.")
# Out:
# 2025-08-02 20:59:34,884 - INFO - Load pretrained SentenceTransformer: Alibaba-NLP/gte-multilingual-base
# Usando dispositivo para embeddings: cpu
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File e:\ANACONDA\envs\rag\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1429 try:
# -> 1430     response.begin()
#    1431 except ConnectionError:
#
# File e:\ANACONDA\envs\rag\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File e:\ANACONDA\envs\rag\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File e:\ANACONDA\envs\rag\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     719 try:
# --> 720     return self._sock.recv_into(b)
#     721 except timeout:
#
# File e:\ANACONDA\envs\rag\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#
# File e:\ANACONDA\envs\rag\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1102 if buffer is not None:
# -> 1103     return self._sslobj.read(len, buffer)
#    1104 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 19
#      13 model_kwargs = {
#      14     'device': device,
#      15     'trust_remote_code': True
#      16 }
#      18 # 3. Inicializar el modelo de embeddings con los argumentos correctos
# ---> 19 embeddings = HuggingFaceEmbeddings(
#      20     model_name="Alibaba-NLP/gte-multilingual-base",
#      21     model_kwargs=model_kwargs
#      22 )
#      24 # Configuración
#      25 COLLECTION_NAME = "idearq-gte"
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:94, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      91 else:
#      92     model_cls = sentence_transformers.SentenceTransformer
# ---> 94 self._client = model_cls(
#      95     self.model_name, cache_folder=self.cache_folder, **self.model_kwargs
#      96 )
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\sentence_transformers\SentenceTransformer.py:309, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, similarity_fn_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, truncate_dim, model_kwargs, tokenizer_kwargs, config_kwargs, model_card_data, backend)
#     306     if "/" not in model_name_or_path and model_name_or_path.lower() not in basic_transformer_models:
#     307         # A model from sentence-transformers
#     308         model_name_or_path = __MODEL_HUB_ORGANIZATION__ + "/" + model_name_or_path
# --> 309 has_modules = is_sentence_transformer_model(
#     310     model_name_or_path,
#     311     token,
#     312     cache_folder=cache_folder,
#     313     revision=revision,
#     314     local_files_only=local_files_only,
#     315 )
#     316 if (
#     317     has_modules
#     318     and self._get_model_type(
#    (...)    325     == self._model_config["model_type"]
#     326 ):
#     327     modules, self.module_kwargs = self._load_sbert_model(
#     328         model_name_or_path,
#     329         token=token,
#    (...)    336         config_kwargs=config_kwargs,
#     337     )
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\sentence_transformers\util.py:1680, in is_sentence_transformer_model(model_name_or_path, token, cache_folder, revision, local_files_only)
#    1659 def is_sentence_transformer_model(
#    1660     model_name_or_path: str,
#    1661     token: bool | str | None = None,
#    (...)   1664     local_files_only: bool = False,
#    1665 ) -> bool:
#    1666     """
#    1667     Checks if the given model name or path corresponds to a SentenceTransformer model.
#    1668
#    (...)   1677         bool: True if the model is a SentenceTransformer model, False otherwise.
#    1678     """
#    1679     return bool(
# -> 1680         load_file_path(
#    1681             model_name_or_path,
#    1682             "modules.json",
#    1683             token=token,
#    1684             cache_folder=cache_folder,
#    1685             revision=revision,
#    1686             local_files_only=local_files_only,
#    1687         )
#    1688     )
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\sentence_transformers\util.py:1723, in load_file_path(model_name_or_path, filename, subfolder, token, cache_folder, revision, local_files_only)
#    1721 file_path = Path(subfolder, filename)
#    1722 try:
# -> 1723     return hf_hub_download(
#    1724         model_name_or_path,
#    1725         filename=file_path.name,
#    1726         subfolder=file_path.parent.as_posix(),
#    1727         revision=revision,
#    1728         library_name="sentence-transformers",
#    1729         token=token,
#    1730         cache_dir=cache_folder,
#    1731         local_files_only=local_files_only,
#    1732     )
#    1733 except Exception:
#    1734     return None
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\huggingface_hub\file_download.py:1008, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     981     if local_dir_use_symlinks != "auto":
#     982         warnings.warn(
#     983             "`local_dir_use_symlinks` parameter is deprecated and will be ignored. "
#     984             "The process to download files to a local folder has been updated and do "
#    (...)    987             "For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder."
#     988         )
#     990     return _hf_hub_download_to_local_dir(
#     991         # Destination
#     992         local_dir=local_dir,
#     993         # File info
#     994         repo_id=repo_id,
#     995         repo_type=repo_type,
#     996         filename=filename,
#     997         revision=revision,
#     998         # HTTP info
#     999         endpoint=endpoint,
#    1000         etag_timeout=etag_timeout,
#    1001         headers=hf_headers,
#    1002         proxies=proxies,
#    1003         token=token,
#    1004         # Additional options
#    1005         cache_dir=cache_dir,
#    1006         force_download=force_download,
#    1007         local_files_only=local_files_only,
# -> 1008     )
#    1009 else:
#    1010     return _hf_hub_download_to_cache_dir(
#    1011         # Destination
#    1012         cache_dir=cache_dir,
#    (...)   1026         force_download=force_download,
#    1027     )
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\huggingface_hub\file_download.py:1071, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1068     if os.path.exists(pointer_path) and not force_download:
#    1069         return pointer_path
# -> 1071 # Try to get metadata (etag, commit_hash, url, size) from the server.
#    1072 # If we can't, a HEAD request error is returned.
#    1073 (url_to_download, etag, commit_hash, expected_size, xet_file_data, head_call_error) = _get_metadata_or_catch_error(
#    1074     repo_id=repo_id,
#    1075     filename=filename,
#    (...)   1085     relative_filename=relative_filename,
#    1086 )
#    1088 # etag can be None for several reasons:
#    1089 # 1. we passed local_files_only.
#    1090 # 2. we don't have a connection
#    (...)   1096 # If the specified revision is a commit hash, look inside "snapshots".
#    1097 # If the specified revision is a branch or tag, look inside "refs".
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\huggingface_hub\file_download.py:1533, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder)
#    1521 if local_files_only:
#    1522     return (
#    1523         None,
#    1524         None,
#    (...)   1530         ),
#    1531     )
# -> 1533 url = hf_hub_url(repo_id, filename, repo_type=repo_type, revision=revision, endpoint=endpoint)
#    1534 url_to_download: str = url
#    1535 etag: Optional[str] = None
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\huggingface_hub\file_download.py:1450, in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers)
#    1410 @validate_hf_hub_args
#    1411 def get_hf_file_metadata(
#    1412     url: str,
#    (...)   1420     endpoint: Optional[str] = None,
#    1421 ) -> HfFileMetadata:
#    1422     """Fetch metadata of a file versioned on the Hub for a given url.
#    1423
#    1424     Args:
#    1425         url (`str`):
#    1426             File url, for example returned by [`hf_hub_url`].
#    1427         token (`str` or `bool`, *optional*):
#    1428             A token to be used for the download.
#    1429                 - If `True`, the token is read from the HuggingFace config
#    1430                   folder.
#    1431                 - If `False` or `None`, no token is provided.
#    1432                 - If a string, it's used as the authentication token.
#    1433         proxies (`dict`, *optional*):
#    1434             Dictionary mapping protocol to the URL of the proxy passed to
#    1435             `requests.request`.
#    1436         timeout (`float`, *optional*, defaults to 10):
#    1437             How many seconds to wait for the server to send metadata before giving up.
#    1438         library_name (`str`, *optional*):
#    1439             The name of the library to which the object corresponds.
#    1440         library_version (`str`, *optional*):
#    1441             The version of the library.
#    1442         user_agent (`dict`, `str`, *optional*):
#    1443             The user-agent info in the form of a dictionary or a string.
#    1444         headers (`dict`, *optional*):
#    1445             Additional headers to be sent with the request.
#    1446         endpoint (`str`, *optional*):
#    1447             Endpoint of the Hub. Defaults to <https://huggingface.co>.
#    1448
#    1449     Returns:
# -> 1450         A [`HfFileMetadata`] object containing metadata such as location, etag, size and
#    1451         commit_hash.
#    1452     """
#    1453     hf_headers = build_hf_headers(
#    1454         token=token,
#    1455         library_name=library_name,
#    (...)   1458         headers=headers,
#    1459     )
#    1460     hf_headers["Accept-Encoding"] = "identity"  # prevent any compression => we want to know the real size of the file
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\huggingface_hub\file_download.py:286, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     284 # Recursively follow relative redirects
#     285 if follow_relative_redirects:
# --> 286     response = _request_wrapper(
#     287         method=method,
#     288         url=url,
#     289         follow_relative_redirects=False,
#     290         **params,
#     291     )
#     293     # If redirection, we redirect only relative paths.
#     294     # This is useful in case of a renamed repository.
#     295     if 300 <= response.status_code <= 399:
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\huggingface_hub\file_download.py:309, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     306     return response
#     308 # Perform request and return if status_code is not in the retry list.
# --> 309 response = http_backoff(method=method, url=url, **params, retry_on_exceptions=(), retry_on_status_codes=(429,))
#     310 hf_raise_for_status(response)
#     311 return response
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\huggingface_hub\utils\_http.py:310, in http_backoff(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, **kwargs)
#     307     kwargs["data"].seek(io_obj_initial_pos)
#     309 # Perform request and return if status_code is not in the retry list.
# --> 310 response = session.request(method=method, url=url, **kwargs)
#     311 if response.status_code not in retry_on_status_codes:
#     312     return response
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\huggingface_hub\utils\_http.py:96, in UniqueRequestIdAdapter.send(self, request, *args, **kwargs)
#      94     logger.debug(f"Send: {_curlify(request)}")
#      95 try:
# ---> 96     return super().send(request, *args, **kwargs)
#      97 except requests.RequestException as e:
#      98     request_id = request.headers.get(X_AMZN_TRACE_ID)
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File e:\ANACONDA\envs\rag\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File e:\ANACONDA\envs\rag\Lib\http\client.py:1446, in HTTPConnection.getresponse(self)
#    1444     return response
#    1445 except:
# -> 1446     response.close()
#    1447     raise
#
# File e:\ANACONDA\envs\rag\Lib\http\client.py:430, in HTTPResponse.close(self)
#     427     self.fp = None
#     428     fp.close()
# --> 430 def close(self):
#     431     try:
#     432         super().close() # set "closed" flag
#
# KeyboardInterrupt:

# %%
from qdrant_client import QdrantClient
client = QdrantClient(url="http://localhost:6333")

COLLECTION_NAME = "idearq-gte" 

print("\n--- Verificación en Qdrant ---")
print(f"Información de la colección '{COLLECTION_NAME}':")

# Usamos client.count() para obtener el número exacto de vectores
try:
    count_result = client.count(
        collection_name=COLLECTION_NAME, 
        exact=True
    )
    
    total_vectors = count_result.count
    
    if 'all_splits' in locals():
      print(f" - Chunks procesados en esta ejecución: {len(all_splits)}")

    print(f" - Número TOTAL de vectores en la colección: {total_vectors}")

except Exception as e:
    print(f"No se pudo obtener el conteo de la colección '{COLLECTION_NAME}'. Error: {e}")
# Out:
# 2025-08-02 20:59:52,498 - INFO - HTTP Request: GET http://localhost:6333 "HTTP/1.1 200 OK"
# 2025-08-02 20:59:52,677 - INFO - HTTP Request: POST http://localhost:6333/collections/idearq-gte/points/count "HTTP/1.1 200 OK"
# --- Verificación en Qdrant ---
# Información de la colección 'idearq-gte':
#  - Chunks procesados en esta ejecución: 50687
#  - Número TOTAL de vectores en la colección: 50687

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt_template = """
Eres un asistente experto en Prehistoria y Arqueología. Tu tarea es responder a la pregunta del usuario de forma clara y concisa, utilizando únicamente la información proporcionada en el siguiente contexto.

Contexto:
{context}

Pregunta: {query}

Instrucciones:
1. Lee la pregunta y el contexto cuidadosamente.
2. Sintetiza la información de los diferentes fragmentos del contexto para formular una respuesta completa.
3. Si el contexto contiene fechas o cronologías relevantes para la pregunta, asegúrate de incluirlas en tu respuesta.
4. Si el contexto no contiene información suficiente para responder a la pregunta, responde honestamente que no puedes encontrar la respuesta en la información proporcionada. No inventes información.

Respuesta:
"""

prompt = ChatPromptTemplate.from_template(prompt_template)

# %%
# Estado del grafo con Pydantic
class State(BaseModel):
    question: str
    context: List[Document] = Field(default_factory=list)
    answer: Optional[str] = None

# Nodo retrieve
def retrieve(state: State) -> dict:
    retrieved_docs = vector_store.similarity_search(state.question, k= 4)
    return {"context": retrieved_docs}

# Nodo generate
def generate(state: State) -> dict:
    docs_content = "\n\n".join(doc.page_content for doc in state.context)
    messages = prompt.invoke({"query": state.question, "context": docs_content})
    response = llm.invoke(messages)
    return {"answer": response}

graph_builder = StateGraph(State).add_sequence([retrieve, generate])
graph_builder.add_edge(START, "retrieve")
graph = graph_builder.compile()

# %%
result = graph.invoke({"question": "¿Cuáles son las dataciones más antiguas para el Neolítico Peninsular?"})

print(f"Context: {result['context']}\n\n")
print(f"Answer: {result['answer']}")
# Out:
# 2025-08-02 21:00:01,600 - INFO - HTTP Request: POST http://localhost:6333/collections/idearq-gte/points/search "HTTP/1.1 200 OK"
# 2025-08-02 21:00:45,085 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Context: [Document(metadata={'producer': 'Acrobat Distiller 7.0 for Macintosh', 'creator': 'QuarkXPress: pictwpstops filter 1.0', 'creationdate': '2006-12-01T07:47:33+01:00', 'source': 'pdf_articulos_idearq\\616_2006.pdf', 'file_path': 'pdf_articulos_idearq\\616_2006.pdf', 'total_pages': 301, 'format': 'PDF 1.7', 'title': 'capitol 1-bo', 'author': 'Maria Pilar', 'subject': '', 'keywords': '', 'moddate': '2010-02-04T13:02:44+01:00', 'trapped': '', 'modDate': "D:20100204130244+01'00'", 'creationDate': "D:20061201074733+01'00'", 'start_index': 538555, '_id': 'b2506598-c5e2-4695-8f11-4c0fa442130e', '_collection_name': 'idearq-gte'}, page_content='que nos introduce directamente en la problemática de la expansión del Neolítico\na escala peninsular. \nEn la década de los años 90 del pasado s. XX los estudios sobre el Neolítico vivie-\nron una auténtica revolución empírica. Fruto de proyectos de investigación progra-\nmados e intervenciones de urgencia, se excavaron y dieron a conocer una amplia\nserie de nuevas estaciones ubicadas dentro y, sobre todo, fuera de las regiones\n“clásicas”: el área mediterránea peninsular.\nResumiendo el amplio volumen de documentación generada desde entonces,\npodríamos decir que fruto de este intenso trabajo, hoy conocemos mejor la geo-\ngrafía de la neolitización peninsular y sabemos que antes del 5000 cal. a.C., no\nsólo el área mediterránea, sino también las cuencas interiores del Ebro,\nGuadalquivir, Tajo y Duero presentan evidencias claras de ocupaciones neolíticas\nen las que la domesticación de plantas y animales está presente. Incluso las pri-'), Document(metadata={'producer': 'Adobe PDF Library 10.0.1', 'creator': 'Adobe InDesign CS6 (Macintosh)', 'creationdate': '2016-06-15T14:27:04+02:00', 'source': 'pdf_articulos_idearq\\940_EnterramientosNeolitico_2016.pdf', 'file_path': 'pdf_articulos_idearq\\940_EnterramientosNeolitico_2016.pdf', 'total_pages': 30, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2016-06-15T14:27:38+02:00', 'trapped': '', 'modDate': "D:20160615142738+02'00'", 'creationDate': "D:20160615142704+02'00'", 'start_index': 115134, '_id': '10bde30d-2af1-4a6e-b28d-90d27e857562', '_collection_name': 'idearq-gte'}, page_content='caso de está necrópolis y el inhumado en Fuente Celada tienen \nuna orientación NW mientras que el único individuo inhumado \ncon una orientación W se da en Paternanbidea.\nPara concluir, nos gustaría ofrecer una interpretación de los \npuntos anteriores desde la perspectiva del proceso de neoliti\xad\nziación y del Neolítico Antiguo en el Interior y en la Península \nIbérica en general. En nuestra opinión (Rojo et al., 2008; Gar\xad\ncía-Martínez de Lagrán et al., 2011; García-Martínez de Lagrán, \n2012, 2014, 2015) la extensión del Neolítico por la Península \nIbérica podría articularse en dos etapas. La primera, el proce\xad\nso de neolitización propiamente dicho, entre el 5700-5600 y el \n5300-5200 cal AC. Entendemos como tal, el periodo de contac\xad\nto, interacción y convivencia de grupos neolíticos pioneros y \ngrupos indígenas de cazadores-recolectores. A partir del 5300-\n5200 esta situación tiene como resultado el inicio del Neolítico'), Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'PScript5.dll Version 5.2', 'creationdate': '2007-09-27T17:11:37+01:00', 'source': 'pdf_articulos_idearq\\605_2005.pdf', 'file_path': 'pdf_articulos_idearq\\605_2005.pdf', 'total_pages': 187, 'format': 'PDF 1.6', 'title': 'Microsoft Word - Pages from 1 to 44.doc', 'author': 'Enrique', 'subject': '', 'keywords': '', 'moddate': '2019-10-28T17:17:41+00:00', 'trapped': '', 'modDate': 'D:20191028171741Z', 'creationDate': "D:20070927171137+01'00'", 'start_index': 26275, '_id': '36db36e5-3364-481c-94f9-fd7e3600d64d', '_collection_name': 'idearq-gte'}, page_content='ámbito como la cuenca del Tajo extremeño muestra a lo \nlargo de toda la Prehistoria reciente, argumento que tam-\npoco reivindica la exclus ...
#
#
# Answer: Según el contexto, las dataciones más antiguas para el Neolítico Peninsular son del período entre los 5700 y 5600 a.C., aunque se menciona que antes de este período ya hay evidencias claras de ocupaciones neolíticas en las cuencas interiores del Ebro, Guadalquivir, Tajo y Duero, lo que sugiere que la neolitización comenzó en la Península Ibérica antes de 5000 a.C.
#
# En particular, se menciona que el proceso de neolitización se divide en dos etapas: la primera, entre los 5700-5600 y el 5300-5200 a.C., durante la cual ocurren las interacciones y convivencias entre grupos neolíticos pioneros y grupos indígenas de cazadores-recolectores.
#
# No se proporcionan fechas específicas más antiguas que indiquen una datación del Neolítico Peninsular, pero se sugiere que la neolitización comenzó en la región mucho antes del 5000 a.C.

# %%
result = graph.invoke({"question": "¿Hay evidencias de caballo doméstico en el Calcolítico peninsular?"})

print(f"Context: {result['context']}\n\n")
print(f"Answer: {result['answer']}")
# Out:
# 2025-08-02 21:01:11,505 - INFO - HTTP Request: POST http://localhost:6333/collections/idearq-gte/points/search "HTTP/1.1 200 OK"
# 2025-08-02 21:01:14,510 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Context: [Document(metadata={'producer': 'Acrobat Distiller 10.1.16 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2017-11-03T10:30:29+01:00', 'source': 'pdf_articulos_idearq\\993_Bartelheim_et_al_Iberian Chalcolithic_2017.pdf', 'file_path': 'pdf_articulos_idearq\\993_Bartelheim_et_al_Iberian Chalcolithic_2017.pdf', 'total_pages': 315, 'format': 'PDF 1.4', 'title': 'A9REA4E.tmp.pdf', 'author': 'Michelau', 'subject': '', 'keywords': '', 'moddate': '2017-11-03T10:30:29+01:00', 'trapped': '', 'modDate': "D:20171103103029+01'00'", 'creationDate': "D:20171103103029+01'00'", 'start_index': 330392, '_id': '915146c5-ed14-46f8-8918-1001ad4380e7', '_collection_name': 'idearq-gte'}, page_content='phase in terms of domestication processes, espe-\ncially with regard to equids, with different debates \nconcerning the existence of an Iberian refugium \nafter the Pleistocene, and the wild or domestic \nstatus of the horses in the 3rd mill. BC (Uerpmann \n1990; 1995; Benecke 1994; Levine 2003; Liesau \n2005; Sommer et al. 2011). It is generally assumed \nthat Peninsular Chalcolithic horses are an agrio-\ntype and even genetically show an isolation phe-\nnomenon (bottleneck) until the Bronze Age, when \nthere began to be greater variability, thus show-\ning that they were not domesticated in the Iberian \nPeninsula (Cieslak et al. 2010). A recent DNA study \nhas shown that domestic asses were present at \nthe Portuguese Chalcolithic site of Leceia (Cardoso \net al. 2013), a discovery that has further compli-\ncated our understanding of equids in the Iberian \nPeninsula and the extinction process of the wild\n\x0cFauna in Living and Funerary Contexts of the 3rd Millennium BC in Central Iberia\n109'), Document(metadata={'producer': 'Acrobat Distiller 10.1.16 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2017-11-03T10:30:29+01:00', 'source': 'pdf_articulos_idearq\\993_Bartelheim_et_al_Iberian Chalcolithic_2017.pdf', 'file_path': 'pdf_articulos_idearq\\993_Bartelheim_et_al_Iberian Chalcolithic_2017.pdf', 'total_pages': 315, 'format': 'PDF 1.4', 'title': 'A9REA4E.tmp.pdf', 'author': 'Michelau', 'subject': '', 'keywords': '', 'moddate': '2017-11-03T10:30:29+01:00', 'trapped': '', 'modDate': "D:20171103103029+01'00'", 'creationDate': "D:20171103103029+01'00'", 'start_index': 736846, '_id': '7eae0c4e-55f4-479d-bea9-9b92d789fd56', '_collection_name': 'idearq-gte'}, page_content='the 2nd mill. BCE, as shown by a wide range of ev-\nidence. To this, it must be added that strong evi-\ndence indicative of the existence of a domestic ass \nin Chalcolithic Iberia has been  recently published \n(Cardoso et al. 2014) for the site of Leceia in Cen-\ntral Portugal. 9 In short, it could be argued that al-\nthough there is no conclusive evidence as yet, one \ninteresting element for future research is to look at \nto what extent equids may have constituted a stra-\ntegic element of Valencina’s economy during the \n3rd mill. BCE. Horse domestication would be rath-\ner consistent with the high level of supra- regional \nconnectivity that these communities had, as \ndemonstrated by other types of evidence – notably \nthe rare stones and exotic raw materials discussed \nbelow.\nAll in all, the available evidence suggests that \nValencina was witness to an important animal- \nEUHHGLQJ\x03HFRQRP\\\x03WKDW\x03ZRXOG\x03KDYH\x03KDG\x03D\x03VLJQLȴ\x10\ncant projection on the symbolic world 10 – for'), Document(metadata={'producer': 'Acrobat Distiller 6.0 (Windows)', 'creator': 'PScript5.dll Version 5.2', 'creationdate': '2007-09-27T17:11:37+01:00', 'source': 'pdf_articulos_idearq\\605_2005.pdf', 'file_path': 'pdf_articulos_idearq\\605_2005.pdf', 'total_pages': 187, 'format': 'PDF 1.6', 'title': 'Microsoft Word - Pages from 1 to 44.doc', 'author': 'Enrique', 'subject': '', 'keywords': '', 'moddate': '2019-10-28T17:17:41+00:00', 'trapped': '', 'modDate': 'D:20191028171741Z', 'creationDate': "D:20070927171137+01'00'", 'start_ind ...
#
#
# Answer: En el Calcolítico peninsular, las evidencias disponibles sugieren que los caballos eran una especie importante en la economía y simbólica de Valencina durante el 3er milenio BCE. Sin embargo, no se considera que los caballos fuesen completamente domesticados hasta la Edad del Bronce, como se demuestra en yacimientos cercanos a Valencina.
#
# Los restos equinos encontrados en el sitio de Leceia, en Central Portugal, sugieren que había presencia de asnos domésticos en esta época. Sin embargo, la falta de evidencia concreta sobre caballos domésticos en Valencina misma, y considerando la importancia de los equídeos en el comportamiento animal en el sitio, se puede inferir que estos animales eran capturados por caza aleatoria o seleccionados para su carne.
#
# En resumen, aunque hay evidencias de utilización de caballos como fuente de alimentación y aprovechamiento cárnico durante el Calcolítico peninsular en Valencina, no se considera que estos animales fuesen completamente domesticados en esta época.

# %%
result = graph.invoke({"question": "¿Cuál es la secuencia cultural de la Prehistoria y Protohistoria de Portugal?"})

print(f"Context: {result['context']}\n\n")
print(f"Answer: {result['answer']}")
# Out:
# 2025-08-02 21:01:55,053 - INFO - HTTP Request: POST http://localhost:6333/collections/idearq-gte/points/search "HTTP/1.1 200 OK"
# 2025-08-02 21:01:57,964 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Context: [Document(metadata={'producer': 'ilovepdf.com', 'creator': '', 'creationdate': '', 'source': 'pdf_articulos_idearq\\989_El-enclave-neolitico-al-aire-libre-del-Castillo-de-Dona-Mencia-Cordoba-Una-mirada-a-los-primeros-agricultores-y-ganaderos_2017.pdf', 'file_path': 'pdf_articulos_idearq\\989_El-enclave-neolitico-al-aire-libre-del-Castillo-de-Dona-Mencia-Cordoba-Una-mirada-a-los-primeros-agricultores-y-ganaderos_2017.pdf', 'total_pages': 28, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2018-06-11T11:42:27+02:00', 'trapped': '', 'modDate': "D:20180611114227+02'00'", 'creationDate': '', 'start_index': 30923, '_id': 'df20872d-736d-4e58-a2dc-2e226c221d33', '_collection_name': 'idearq-gte'}, page_content='sente e futuros, In: Diniz, M., Neves, C., Martins, A. (Eds.), O Neolítico em Portugal \nantes do Horizonte 2020: Perstectivas em debate. Associaçao dos Arqueólogos \nPortugueses, Lisboa, pp. 87-108.\nValente, M.J., Dean, R.M., Carvalho, A.F., 2014. Shell Middens in Western Algarve \n(Southern Portugal) During the Mesolithic and Early Neolithic, In: Roksandic, M., \nMendoça de Souza, S., Eggers, S., Brurchell, M., Klokler, D. (Eds.), The Cultural \nDynamics of Shell-Matrix Sites. University of New Mexico, Alburquerque, pp. 75-\n90.\nValera Pérez, R., 2007. Arqueología. Ocupación prehistórica del yacimiento de Caño \nBajo (T.M. La Rambla, Córdoba). Arte, Arqueología e Historia 16, 128-131.\nVera Rodríguez, J.C., Gavilán Ceballos, B., Peña-Chocarro, L., Cepillo Galvín, J., \nMarfil Lopera, C., Martínez Fernández, M.J., Rafael Penco, J.J., Sánchez Guijarro, \nE., 1999. Prehistoria, In: Molina Expósito, A. (Ed.), Zuheros. Un recorrido por su \npasado. Ayuntamiento de Zuheros, Zuheros, pp. 13-20.'), Document(metadata={'producer': '', 'creator': 'Elsevier', 'creationdate': '2020-04-03T09:58:55+00:00', 'source': 'pdf_articulos_idearq\\1093_adressing_2020.pdf', 'file_path': 'pdf_articulos_idearq\\1093_adressing_2020.pdf', 'total_pages': 14, 'format': 'PDF 1.7', 'title': 'Addressing human mobility in Iberian Neolithic and Chalcolithic ditched enclosures_ The case of Perdigões (South Portugal)', 'author': 'A.C. Valera', 'subject': 'Journal of Archaeological Science: Reports, 30 (2020) 102264. doi:10.1016/j.jasrep.2020.102264', 'keywords': 'Mobility; Strontium isotope analysis; Neolithic; Chalcolithic; Perdigões; Prehistoric enclosures;', 'moddate': '2020-04-03T09:58:55+00:00', 'trapped': '', 'modDate': 'D:20200403095855Z', 'creationDate': 'D:20200403095855Z', 'start_index': 66061, '_id': 'daa5da56-c5a8-40b4-8d7e-7a3e2a7f7bdf', '_collection_name': 'idearq-gte'}, page_content='and the 3rd millennium cal BC. Proc. Prehistoric Soc. 73, 327–380.\nHillier, M., Boaventura, R., Grimes, V., 2011. Moving around? Testing mobility with\nstrontium isotopes (86Sr/87Sr) in the Late Neolithic of SouthCentral Portugal. IX\nCongresso de Arqueologia do Algarve, Silves.\nIñigo et al., 2019. The genomic history of the Iberian Peninsula over the past 8000 years,\nScience, vol.363, issue 6432, 1230-1234. Doi: 10.1126/science.aav4040.\nJorge, S.O., 1990. Desenvolvimento da hierarquização social e da metalurgia, in: Serrão,\nS., Oliveira Marques, A.H. (eds.), Nova História de Portugal. Portugal, das origens à\nromanização, Lisboa, pp. 163–212.\nJorge, S.O., 1999. Domesticar a terra. Gradiva, Lisboa.\nLago, M., Duarte, C., Valera, A.C., Albergaria, J., Almeida, F., Carvalho, A., 1998.\nPovoado dos Perdigões (Reguengos de Monsaraz): dados preliminares dos trabalhos\narqueológicos realizados em 1997. Revista Portuguesa de Arqueologia 1 (1), 45–152.'), Document(metadata={'producer': '', 'creator': 'Elsevier', 'creationdate': '2020-09-03T10:58:35+00:00', 'source': 'pdf_articulos_idearq\\1094_Pleistocene_2020.pdf', 'file_path': 'pdf_articulos_idearq\\1094_Pleistocene_2020.pdf', 'total_pages': 25, 'format': 'PDF 1.7', 'title': 'Archaeology of the Pleistocene-Holocene transition in Portugal_ Synthesis and prospects', 'a ...
#
#
# Answer: Basándome en el contexto proporcionado, puedo sintetizar la secuencia cultural de la Prehistoria y Protohistoria de Portugal de la siguiente manera:
#
# La prehistoria portuguesa se puede dividir en varias fases, que van desde el Paleolítico hasta el Neolítico. A continuación, se presentan las fases mencionadas en el contexto:
#
# * Paleolítico (hace aproximadamente 400.000-19.500 años cal BP): En este período, los humanos portugueses estaban en la fase de hunter-gatherers. Se han encontrado restos de animales y artefactos líticos en este período.
# * Magdaleniano (hace aproximadamente 19.500-14.000 años cal BP): Este es un subperiodo del Paleolítico Final. Se divide en tres fases:
#  + Magdaleniano Temprano (hace aproximadamente 19.500-16.000 años cal BP)
#  + Magdaleniano Superior (hace aproximadamente 16.000-14.500 años cal BP)
#  + Magdaleniano Final (hace aproximadamente 14.500-13.000 años cal BP)
# * Neolítico (hace aproximadamente 14.500-13.000 años cal BP): Este es un período de transición entre la prehistoria y la historia antigua. Se caracteriza por la introducción del cultivo de cereales y el uso de herramientas de piedra más sofisticadas.
# * Protohistoria (hace aproximadamente 13.000-11.500 años cal BP): Este es un período que se considera parte de la prehistoria, pero también está relacionado con la llegada de pueblos invasores desde el norte de África y el Mediterráneo.
#
# Es importante mencionar que la secuencia cultural de Portugal puede variar dependiendo del lugar específico y de las fechas radiocarbonicas disponibles. Sin embargo, en general, este es el esquema cronológico más aceptado para la prehistoria y protohistoria de Portugal.
#
# En cuanto a la "secuencia cultural clásica" mencionada en el contexto, se refiere a la secuencia de fases del Paleolítico Final en el sur de Francia, que se considera un modelo para entender la evolución cultural en Europa. Sin embargo, como se menciona en el contexto, esta secuencia no es directamente aplicable a Portugal, ya que la prehistoria portuguesa se caracteriza por una mayor variedad tecnológica y cronológica.

# %%
result = graph.invoke({"question": "¿Cuándo se produce el poblamiento de Baleares?"})

print(f"Context: {result['context']}\n\n")
print(f"Answer: {result['answer']}")
# Out:
# 2025-08-02 21:02:57,174 - INFO - HTTP Request: POST http://localhost:6333/collections/idearq-gte/points/search "HTTP/1.1 200 OK"
# 2025-08-02 21:02:59,995 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Context: [Document(metadata={'producer': 'Acrobat Distiller 8.1.0 (Windows); modified using iTextSharp™ 5.5.8 ©2000-2015 iText Group NV (AGPL-version)', 'creator': 'Servigistics Arbortext Advanced Print Publisher 11.1.4546/W-x64', 'creationdate': '2022-08-29T11:32:56+05:30', 'source': 'pdf_articulos_idearq\\1132_Caprine mobility_2021.pdf', 'file_path': 'pdf_articulos_idearq\\1132_Caprine mobility_2021.pdf', 'total_pages': 13, 'format': 'PDF 1.4', 'title': 'Caprine Mobility on the Balearic Islands During the Middle and Late Bronze Age (ca. 1600–850 BC): Fi', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2022-08-29T11:34:58+05:30', 'trapped': '', 'modDate': "D:20220829113458+05'30'", 'creationDate': "D:20220829113256+05'30'", 'start_index': 41771, '_id': '2e9bc357-1d3b-4b4c-af98-6e029c4146cc', '_collection_name': 'idearq-gte'}, page_content='“Cultura material, habitus, espacio y movilidad en el\narchipiélago balear durante el Bronce Final I (c. 1400–\n1100BC).” Bolletí de la Societat Arqueològica Lul·liana,\nRevista d’Estudis Històrics 865: 15–37.\nAnglada, M., A. Ferrer, D. Ramis, and M. Salas. 2013.\n“Resultats preliminars del Projecte Entre Illes: El cas\ndels jaciments de Sa Ferradura (Manacor) i Cala Morell\n(Ciutadella).” In V Jornades d’Arqueologia de les Illes\nBalears, edited by M. Riera, and J. Cardell, 51–58.\nPalma: Edicions Documenta.\nAnglada, M., A. Ferrer, D. Ramis, and M. Salas. 2015. “Les\nllars de foc en els caps costaners de Sa Ferradura\n(Manacor) i Es Coll de Cala Morell (Ciutadella.” In\nL’entreteixit del temps. Miscel·lània d’estudis en home-\nnatge a Lluís Plantalamor, edited by C. Andreu, C.\nFerrando, and O. Pons, 59–72. Palma: Govern de les\nIlles Balears.\nAnglada, M., A. Ferrer, D. Ramis, M. Salas, M. Strydonck, M.\nJ. León, and L. Plantalamor. 2017. “Dating Prehistoric\nFortiﬁed\nCoastal\nSites\nin\nthe\nBalearic'), Document(metadata={'producer': 'Acrobat Distiller 8.1.0 (Windows); modified using iTextSharp™ 5.5.8 ©2000-2015 iText Group NV (AGPL-version)', 'creator': 'Servigistics Arbortext Advanced Print Publisher 11.1.4546/W-x64', 'creationdate': '2022-08-29T11:32:56+05:30', 'source': 'pdf_articulos_idearq\\1132_Caprine mobility_2021.pdf', 'file_path': 'pdf_articulos_idearq\\1132_Caprine mobility_2021.pdf', 'total_pages': 13, 'format': 'PDF 1.4', 'title': 'Caprine Mobility on the Balearic Islands During the Middle and Late Bronze Age (ca. 1600–850 BC): Fi', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2022-08-29T11:34:58+05:30', 'trapped': '', 'modDate': "D:20220829113458+05'30'", 'creationDate': "D:20220829113256+05'30'", 'start_index': 3235, '_id': 'ba6f4d2b-8f53-4e7e-8ce6-30a3f9cab2e7', '_collection_name': 'idearq-gte'}, page_content='increase knowledge about their social organisation\nand identity (i.e. Broodbank 1993; Knapp and Van\nDommelen 2010). The analysis of space and mobility\non islands can be a challenge because aspects related\nto naval technology or marine infrastructures and\nmobility must be considered (Calvo et al. 2011). For\narchaeology in the Balearic Islands, one of the main\ncurrent research questions is to assess the degree of\ninsular connectivity and mobility of animal and\nhuman populations during the Bronze Age.\nThe Bronze Age on the Balearic Islands is charac-\nterised by the Naviform culture, also called Pretalayo-\ntic or Dwelling Naveta (ca. 1600–850 BC; Lull et al.\n1999; Calvo, Guerrero, and Salvà 2001; Guerrero\net al. 2007; Calvo 2009; although some authors place\nthe end of the Naviform period in the late 2nd millen-\nnium cal BC, see Ramis and Salas 2014; Gelabert, Her-\nnández-Gasch, and Puig 2018) (see supplementary\nmaterial S1). The settlements were open-air villages'), Document(metadata={'producer': '', 'creator': 'Elsevier', 'creationdate': '2019-02-14T13:33:07+00:00', 'source': 'pdf_articulos_idearq\\1070_Deciphering Neolithic_2019.pdf', 'file_path': 'pdf_articulos_idearq\\1070_Deciphering Neolithic_2019.pdf', 'total_pages': 24 ...
#
#
# Answer: Basándome en los fragmentos del contexto proporcionados, puedo decir que no tengo una respuesta clara sobre cuándo se produce el poblamiento de Baleares. El contexto menciona que el período Bronce Final I en el archipiélago balear se caracteriza por la cultura Naviform (ca. 1600-850 BC), pero no proporciona información específica sobre el momento del poblamiento de las Islas Balears.
#
# Sin embargo, se mencionan algunas fechas relevantes para otros aspectos de la prehistoria en Baleares, como la Edad del Bronce en Cataluña (comarcas del Moianès, Vallès Oriental, Vallès Occidental, Maresme, Barcelonès y Baix Llobregat), pero no hay información sobre el momento específico del poblamiento de las Islas Balears.
#
# Por lo tanto, mi respuesta es:
#
# No puedo encontrar la respuesta a esta pregunta en la información proporcionada.

# %% [markdown]
# Ingesta de más embeddings

# %%
# 1. Detectar si hay una GPU disponible
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Usando dispositivo para embeddings: {device}')

# 2. Configurar los argumentos del modelo para incluir el dispositivo y trust_remote_code
model_kwargs = {
    'device': device,
    'trust_remote_code': True
}

# 3. Inicializar el modelo de embeddings con los argumentos correctos
embeddings = HuggingFaceEmbeddings(
    model_name="Alibaba-NLP/gte-multilingual-base",
    model_kwargs=model_kwargs
)
# Out:
# Usando dispositivo para embeddings: cuda
# Some weights of the model checkpoint at Alibaba-NLP/gte-multilingual-base were not used when initializing NewModel: ['classifier.bias', 'classifier.weight']
# - This IS expected if you are initializing NewModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing NewModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
import logging
from pathlib import Path
from langchain.document_loaders import PyMuPDFLoader

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

all_docs = []
folder_path = Path("pdf_articulos_idearq/pdf_articulos_idearq_2subida/") 

logging.info(f"Iniciando la carga de documentos desde: {folder_path.resolve()}")

if not folder_path.is_dir():
    logging.error(f"El directorio especificado no existe: {folder_path.resolve()}")
else:
    for pdf_file in folder_path.glob("*.pdf"):
        try:
            loader = PyMuPDFLoader(str(pdf_file), mode="single")
            docs_from_file = loader.load()
            all_docs.extend(docs_from_file)
            
        except Exception as e:
           
            logging.warning(f"No se pudo cargar el archivo '{pdf_file.name}'. Saltando. Error: {e}")

    logging.info(f"Carga finalizada. Se han cargado un total de {len(all_docs)} documentos.")
# Out:
# 2025-08-12 12:44:25,451 - INFO - Iniciando la carga de documentos desde: C:\Users\elevi\Documents\CSIC\RAG\pdf_articulos_idearq\pdf_articulos_idearq_2subida
# 2025-08-12 12:44:56,205 - INFO - Carga finalizada. Se han cargado un total de 105 documentos.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
import logging

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

text_splitter_config = {
    "chunk_size": 1000,
    "chunk_overlap": 200, # 15-20% de chunk_size
    "length_function": len,
    "add_start_index": True,
    "separators": ["\n\n", "\n", ". ", " ", ""],
}

text_splitter = RecursiveCharacterTextSplitter(**text_splitter_config)
all_splits = text_splitter.split_documents(all_docs)
logging.info(f"Se dividieron {len(all_docs)} documentos en un total de {len(all_splits)} chunks.")
# Out:
# 2025-08-12 12:44:58,329 - INFO - Se dividieron 105 documentos en un total de 27103 chunks.

# %%
from langchain_qdrant import Qdrant

QDRANT_URL = "http://localhost:6333"
COLLECTION_NAME = "idearq-gte"

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
client = QdrantClient(url=QDRANT_URL)
logging.info(f"Conectando a la colección '{COLLECTION_NAME}' a través de LangChain...")
vector_store = Qdrant(
    client=client,
    collection_name=COLLECTION_NAME,
    embeddings=embeddings,
)
logging.info("Objeto 'vector_store' listo para la ingesta")
logging.info(f"Iniciando la ingesta de {len(all_splits)} chunks...")
vector_store.add_documents(all_splits)
logging.info("Ingesta completada")
# Out:
# 2025-08-12 12:44:58,416 - INFO - HTTP Request: GET http://localhost:6333 "HTTP/1.1 200 OK"
# 2025-08-12 12:44:58,419 - INFO - Conectando a la colección 'idearq-gte' a través de LangChain...
# C:\Users\elevi\AppData\Local\Temp\ipykernel_14384\1176655513.py:9: LangChainDeprecationWarning: The class `Qdrant` was deprecated in LangChain 0.1.2 and will be removed in 0.5.0. Use :class:`~QdrantVectorStore` instead.
#   vector_store = Qdrant(
# 2025-08-12 12:44:58,420 - INFO - Objeto 'vector_store' listo para la ingesta
# 2025-08-12 12:44:58,422 - INFO - Iniciando la ingesta de 27103 chunks...
# 2025-08-12 12:45:03,034 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:45:06,195 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:45:09,032 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:45:12,087 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:45:15,458 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:45:18,630 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:45:24,832 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:45:31,842 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:45:47,463 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:45:59,211 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:46:14,546 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:46:26,773 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:46:38,341 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:46:46,803 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:47:02,151 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:47:16,140 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:47:23,897 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:47:35,385 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:47:47,512 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:47:59,184 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:48:07,654 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:48:12,465 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:48:25,294 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:48:41,239 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:48:53,272 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:48:59,105 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:49:15,762 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:49:23,132 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:49:39,382 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:49:56,383 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:50:09,087 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:50:25,923 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:50:41,588 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:50:53,047 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:51:01,089 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:51:13,508 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:51:29,164 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:51:40,249 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:51:50,479 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:51:58,746 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:52:04,370 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:52:16,268 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:52:25,104 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:52:27,684 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:52:30,740 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12:52:33,872 - INFO - HTTP Request: PUT http://localhost:6333/collections/idearq-gte/points?wait=true "HTTP/1.1 200 OK"
# 2025-08-12 12